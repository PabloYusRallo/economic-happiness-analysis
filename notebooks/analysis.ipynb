# %% [markdown]
# # Economic Analysis of Happiness
#
# This project explores the relationship between economic indicators and happiness levels across countries.

# %% [markdown]
# ## Research Question
# Is GDP per capita the main determinant of happiness, or do social and institutional factors also play an important role?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/World Happiness Report/world_happiness_2019.csv")

df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %% [markdown]
# To begin the analysis, we visualize the relationship between our two main variables of interest to better understand their association.

# %%
plt.scatter(df["GDP per capita"], df["Score"])
plt.xlabel("GDP per capita")
plt.ylabel("Happiness score")
plt.title("GDP vs Happiness")
plt.show()

# %% [markdown]
# At first glance, there appears to be a positive relationship between GDP per capita and happiness, with higher-income countries generally reporting higher levels of happiness.

# %% [markdown]
# We now analyze the correlation across all variables to determine which factors are most strongly associated with happiness.

# %%
corr.drop("Score").plot(kind="bar")
plt.title("Factors correlated with Happiness")
plt.show()

# %% [markdown]
# There is a strong positive correlation between GDP per capita and happiness scores, with a correlation coefficient of approximately
# 0.79. This indicates that countries with higher income levels tend, on average, to report higher levels of happiness. However, the relationship is not perfect, suggesting that economic prosperity alone does not fully explain differences in well-being across countries. Some relatively wealthy nations exhibit lower happiness levels, while certain lower-income countries achieve comparatively high happiness scores. For this reason, the analysis will also explore additional factors that may help explain variations in happiness beyond GDP per capita.

# %%
economic = ["GDP per capita"]
social = ["Social support", "Freedom to make life choices", "Healthy life expectancy", "Perceptions of corruption"]

# %%
df[economic + ["Score"]].corr()
# Out:
#                 GDP per capita     Score
# GDP per capita        1.000000  0.793883
# Score                 0.793883  1.000000

# %%
df[social + ["Score"]].corr()
# Out:
#                               Social support  Freedom to make life choices  \
# Social support                      1.000000                      0.447333
# Freedom to make life choices        0.447333                      1.000000
# Healthy life expectancy             0.719009                      0.390395
# Perceptions of corruption           0.181899                      0.438843
# Score                               0.777058                      0.566742
#
#                               Healthy life expectancy  \
# Social support                               0.719009
# Freedom to make life choices                 0.390395
# Healthy life expectancy                      1.000000
# Perceptions of corruption                    0.295283
# Score                                        0.779883
#
#                               Perceptions of corruption     Score
# Social support                                 0.181899  0.777058
# ...

# %% [markdown]
# ## Summary of Findings
#
# GDP per capita shows the strongest correlation with happiness. However, social factors such as social support and healthy life expectancy also display meaningful relationships with well-being.

# %% [markdown]
# ## Conclusion
#
# These results suggest that happiness is influenced by multiple dimensions. While economic prosperity plays a central role, social and health-related factors are also important in explaining differences in well-being across countries.
